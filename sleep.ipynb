# %% [markdown]
# # 수면 데이터 분석: 수면 품질과 수면 장애 영향 요인 연구
# ## 목차
# 1. [데이터 개요](#1-데이터-탐색적-분석)
#    - 데이터셋 개요 및 변수 설명
#    - 기초 통계량 확인
#    - 데이터 특징 요약
#
# 2. [데이터 전처리 및 기초 시각화](#2-데이터-전처리-및-기초-시각화)
#    - 설명 변수 분포 분석
#      - 인구통계학적 변수 (나이, 성별, 직업)
#      - 신체 관련 변수 (BMI, 혈압, 심박수)
#      - 생활습관 변수 (수면시간 ,신체활동량, 일일걸음수)
#      - 정신건강 변수 (스트레스 레벨)
#
# 3. [목표 변수 심층 분석](#3-목표-변수-심층-분석)
#    - 수면 품질 분석
#      - 분포 특성
#      - 주요 영향 요인 분석
#    - 수면 장애 분석
#      - 유형별 특성
#      - 주요 영향 요인 분석
#
# 4. 결론
#    - 주요 발견사항
#    - 수면 개선을 위한 제안
#
# 5. 한계점 및 개선방안
#
# ## 연구 목표
# 1. **수면 품질 영향 요인 식별**
#    - 수면 품질에 영향을 미치는 주요 변수 탐색
#    - 변수 간 상호작용 효과 분석
#
# 2. **수면 장애 관련 요인 분석**
#    - 수면 장애 발생과 관련된 위험 요인 식별
#    - 수면 장애 유형별 특성 비교
#
# 3. **수면 개선 방안 도출**
#    - 분석 결과를 바탕으로 한 실질적 개선 방안 제시
#    - 생활습관 개선 포인트 도출
#
# ## 분석 방법론
# - 탐색적 데이터 분석 (EDA)
# - 시각화 기반 분석
# - 상관관계 분석

# %% [markdown]
# ### 1. 데이터 개요
#
# ---

# %%
#라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib
import seaborn as sns
import numpy as np

# %%
# 데이터셋 불러오기
sleep = pd.read_csv('sleep.csv')
sleep.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# 1         125/80          75        10000            NaN
# 2         125/80          75        10000            NaN
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea

# %% [markdown]
# ---
# ### 변수 설명:
# 1. Person ID: 각 개인을 식별하는 고유 번호
# 2. Gender: 성별(남성/여성)
# 3. Age: 나이(세)
# 4. Occupation: 직업 또는 전문 분야
# 5. Sleep Duration (hours): 일일 수면 시간(시간)
# 6. Quality of Sleep (scale: 1-10): 주관적인 수면의 질 평가(1-10 척도)
# 7. Physical Activity Level (minutes/day): 일일 신체 활동 시간(분)
# 8. Stress Level (scale: 1-10): 주관적인 스트레스 수준 평가(1-10 척도)
# 9. BMI Category: BMI 카테고리(저체중, 정상, 과체중 )
# 10. Blood Pressure (systolic/diastolic): 혈압 측정치(수축기 혈압/이완기 혈압)
# 11. Heart Rate (bpm): 안정 시 심박수(분당 박동 수)
# 12. Daily Steps: 일일 걸음 수
# 13. Sleep Disorder: 수면 장애 유무(없음, 불면증, 수면무호흡증)
# ---

# %%
#간단한 데이터셋 정보 
print(sleep.shape)
sleep.info()
# Out:
# (374, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
# 수치형 데이터 요약통계
sleep.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# 25%                  45.000000      4.000000   68.000000   5600.000000
# 50%                  60.000000      5.000000   70.000000   7000.000000
# 75%                  75.000000      7.000000   72.000000   8000.000000
# max                  90.000000      8.000000   86.000000  10000.000000

# %%
# 범주형 데이터 요약통계
sleep.describe(include='object')
# Out:
#        Gender Occupation BMI Category Blood Pressure Sleep Disorder
# count     374        374          374            374            155
# unique      2         11            4             25              2
# top      Male      Nurse       Normal         130/85    Sleep Apnea
# freq      189         73          195             99             78

# %% [markdown]
# ---
#
# ## 데이터 특징 요약:
# * 결측치: 수면장애를 제외하고 결측치가 없음. 결측치가 특정 값으로 대체되었을 가능성이 있어 보입니다.
# * 변수 요약:
#     1. 이 데이터셋은 총 **374명**의 수면 패턴과 관련된 변수들을 담고 있습니다.
#     2. 성별은 남성이 189명으로, 여성수 185명보다 약간 더 많습니다.
#     3. 대상자들의 나이 범위는 **27세에서 59세**로, 주로 일하는 연령대의 성인들로 구성되어 있습니다.
#     4. 수면 시간은 **5시간 48분**에서 **8시간 30분**까지 분포합니다.
#     5. 수면 품질의 실제 구간은 1-10이 아닌 **4-9**로 확인됩니다.
#     6. 신체 활동 시간은 **30-90분** 사이에 분포합니다.
#     7. 스트레스 레벨의 실제 구간은 1-10이 아닌 **3-8**로 확인됩니다.
#     8. 안정 시 심박수는 **65-86** 사이에 분포합니다.
#     9. 걸음수는 **3,000-10,000** 사이에 분포합니다.
#     10. 직업 종류는 총 11개로, 374명 중 73명이 간호사로 확인되는 것으로 보아 **병원 관련 종사자들을 대상으로 수집되었을 가능성**이 있습니다.
#     11. 혈압은 **130/85**라는 값이 99번 반복되는 것으로 보아, **결측치를 평균값으로 대체**했을 가능성이 높아 보입니다.
#     12. BMI는 정상 범위에 해당하는 사람이 195명입니다.
#     13. 수면 무호흡증을 가진 사람은 총 78명입니다.
#
# ---

# %% [markdown]
# ---
#
# ## 2.전처리 및 시각화
# * 각 변수의 분포 특성을 시각화하여 데이터의 특징을 파악합니다.

# %%
# 시각화 특징 모음 
plt.rcParams.update({'axes.titlesize': 16})
plt.rcParams.update({'font.size': 13})

# %%
# 먼저 수치형 변수들의 분포를 시각화하여 데이터의 특징을 파악합니다.
sns.pairplot(sleep[['Age','Physical Activity Level','Daily Steps','Sleep Duration', 'Quality of Sleep', 
                    'Stress Level', 'Heart Rate']])
plt.suptitle('모든 수치형 변수들의 관계', y=1.02)
plt.show()

# %% [markdown]
# ### 2-1 인구통계학적 변수

# %%
#1.성별과 나이 분포
plt.figure(figsize=(20, 10))
plt.subplot(1, 2, 1)
male_data = sleep[sleep['Gender'] == 'Male']['Age'].value_counts().sort_index()
female_data = sleep[sleep['Gender'] == 'Female']['Age'].value_counts().sort_index()
# 남성 데이터는 음수로 변환하여 왼쪽에 표시
plt.barh(male_data.index, -male_data.values, color='lightblue', label='남성')
# 여성 데이터는 오른쪽에 표시
plt.barh(female_data.index, female_data.values, color='pink', label='여성')
max_count = max(male_data.max(), female_data.max())
plt.xlim(-max_count, max_count)

# x축 레이블 절대값으로 표시
xticks = plt.gca().get_xticks()
plt.gca().set_xticklabels([str(abs(int(x))) for x in xticks])
plt.title('연령별 성별 분포', pad=20);plt.xlabel('인원수');plt.ylabel('나이');plt.legend();plt.grid(True)

# kde 그래프
plt.subplot(1, 2, 2)
sns.kdeplot(data=sleep, x='Age', hue='Gender', palette=['lightblue', 'pink'], common_norm=False, fill=True, alpha=0.4)
plt.title('연령 성별 분포 밀도');plt.xlabel('나이');plt.ylabel('밀도');plt.grid(True);plt.tight_layout();plt.show()

# #요약
# 1. 0-26 세의 인구는 0명입니다.
# 2. 27-59세의 인구로 데이터가 구성되어 있습니다.
# 3. 남성은 27-44세 까지 많이 분포하는 반면 여성은 35-59세까지 많이 분포합니다.
# ### 결론 : 남성과 여성의 나이의 분포 차이가 큼으로 데이터를 분석할때 성별에 따른 차이인지 나이에 따른 차이인지를 구분하기 어려울 수 있습니다.
# Out:
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_46610/710629650.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_xticklabels([str(abs(int(x))) for x in xticks])

# %%
# 2.직업 분포
plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
# Stacked bar plot 생성
occupation_gender = pd.crosstab(sleep['Occupation'], sleep['Gender'])
occupation_gender = occupation_gender.reindex(sleep['Occupation'].value_counts().index)
occupation_gender.plot(kind='barh', stacked=True, color=['pink', 'lightblue'], width=0.8, ax=plt.gca())
plt.title('직업별 성별 분포', fontsize=16);plt.xlabel('인원수', fontsize=12);plt.ylabel('직업', fontsize=12);plt.legend(title='성별');plt.grid(True, axis='x')

#직업별 나이 분포 (boxplot)
plt.subplot(1, 2, 2)
sns.boxplot(y='Occupation', x='Age', hue='Gender', data=sleep,order=sleep['Occupation'].value_counts().index,palette=['lightblue','pink'])
plt.title('직업별 성별 나이 분포');plt.xlabel('나이');plt.ylabel('직업');plt.legend(title='성별');plt.grid(True)
plt.tight_layout()
plt.show()
# #요약
# 1. 무직,학생이 없는 직장인들을 대상으로 수집된 데이터입니다.
# 2. 의료 종사자(간호사+의사)가 전체 인구 374명중 144명인 것으로 보아,직업 분포가 사회의 다양한 직업군을 대표하지 않을 가능성이 높습니다.
# 3. engineer 를 제외한 모든 직업에서 남성과 여성의 성비 차이가 큽니다.
# 4. 직업별 나이 분포 그래프를 확인하면 engineer 여성의 나이 분포가 인원수에 비해 매우 좁게 분포합니다.

# %% [markdown]
# ### 2-2. 신체 관련 변수

# %%
# 3.bmi

# 'Normal Weight'를 'Normal'로 변경
sleep['BMI Category'] = sleep['BMI Category'].replace('Normal Weight', 'Normal')

# BMI 카테고리 분포 시각화
plt.figure(figsize=(10, 8))
bmi_counts = sleep['BMI Category'].value_counts()
plt.pie(bmi_counts, labels=bmi_counts.index, autopct='%1.1f%%')
plt.title('BMI 카테고리 비율')
plt.show()
print("====변수명 변경후===")
print(sleep['BMI Category'].value_counts())

#요약
# 1.동일한 의미를 가진 'Normal'과 'Normal Weight'가 중복되어 있습니다.데이터의 일관성과 위해 'Normal Weight'를 'Normal'로 변경하겠습니다.
# 2.현재 'Under Weight' 카테고리가 누락되어 있습니다.'Under Weight' 카테고리를 'Normal Weight'로 잘못 기입했을 가능성도 있습니다.
# Out:
# ====변수명 변경후===
# BMI Category
# Normal        216
# Overweight    148
# Obese          10
# Name: count, dtype: int64

# %%
# 4.혈압
sleep['Blood Pressure'].value_counts()

plt.figure(figsize=(12, 6))
sns.countplot(data=sleep, x='Blood Pressure',order = sleep['Blood Pressure'].value_counts().index,palette='coolwarm')
plt.title('혈압 값별 빈도수')
plt.xlabel('혈압')
plt.ylabel('빈도수')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#요약
# 1.혈압 데이터는 비정상적으로 특정 값에 몰려 있습니다.
# 2.혈압 빈도수 top2(140/95) 와 top3(125/80)값이 정확히 일치합니다.
# 3.이러한 패턴은 실제 혈압 분포에서 나타나기 어려운 현상입니다.데이터 수집 과정에서 심각한 측정 오류나 기록 편향이 있었을 것으로 추정됩니다.
#결론 : 해당 혈압 데이터는 신뢰성이 매우 낮아 분석에 적합하지 않음으로 사용하지 않겠습니다.
# Out:
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_46610/3239375163.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sleep, x='Blood Pressure',order = sleep['Blood Pressure'].value_counts().index,palette='coolwarm')

# %%
# 5.(안정 상태)심박수
# 심박수 데이터 시각화
plt.figure(figsize=(16, 8))

# 3. 성별에 따른 심박수 분포
plt.subplot(1, 2, 1)
sns.violinplot(data=sleep, x='Gender', y='Heart Rate',palette=['lightblue','pink'])
plt.title('성별에 따른 심박수 분포')
plt.xlabel('성별')
plt.ylabel('심박수 (BPM)')

# 심박수와 스트레스 의 관계
plt.subplot(1, 2, 2)
sns.regplot(data=sleep, x='Heart Rate', y='Stress Level', scatter_kws={'alpha':0.3}, line_kws={'color': 'red'})
plt.title('심박수와 스트레스 레벨의 관계')
plt.xlabel('심박수 (BPM)')
plt.ylabel('스트레스 레벨')
plt.tight_layout()
plt.show()

# 요약 
# 1.심박수 70-72 부근에서 여성의 수가 적은 것은 단순히 남녀의 생물학적 차이라기보다는 남성과 여성의 나이의 분포 차이가 크기 때문 일 수 있습니다.
# 2.심박수가 높을수록 스트레스 레벨이 높아지는 경향이 있습니다.
# Out:
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_46610/2683837727.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=sleep, x='Gender', y='Heart Rate',palette=['lightblue','pink'])

# %% [markdown]
# ### 2-3 생활습관 변수

# %%
# 6.수면 시간
plt.figure(figsize=(16, 8))

# 히스토그램 + KDE
plt.subplot(1, 2, 1)
sns.histplot(data=sleep, x='Sleep Duration', bins=27, kde=True)
plt.title('전체 수면 시간 분포');plt.xlabel('수면 시간 (시간)');plt.ylabel('빈도')

# 박스플롯
plt.subplot(1, 2, 2)
sns.boxplot(data=sleep,hue='Gender', x='Sleep Duration',palette=['lightblue','pink'])
plt.title('수면 시간 상자수염 그래프');plt.xlabel('수면 시간 (시간)');plt.tight_layout()

plt.show()
# #요약
# 1. 수면 시간은 5시간 48분에서 8시간 30분까지 분포하고 있습니다.
# 2. 남성은 여성보다 수면시간이 더 적은 경향이 있습니다.

# %%
#5.신체 활동 분포

# 신체활동 히스토그램 + KDE
plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
sns.histplot(data=sleep, x='Physical Activity Level', bins=30, kde=True)
plt.title('신체 활동 시간 분포');plt.xlabel('신체 활동 시간(분)');plt.ylabel('빈도');plt.grid(True)

# BMI 와 성별에 따른 신체 활동량
plt.subplot(1, 2, 2)
sns.boxplot(data=sleep, x='BMI Category', y='Physical Activity Level', hue='Gender',order=['Normal','Overweight','Obese'] ,palette=['lightblue', 'pink'])
plt.title('BMI와 성별에 따른 신체 활동 레벨');plt.xlabel('BMI');plt.ylabel('신체 활동 시간(분)');plt.xticks(rotation=45);plt.legend(title='성별');plt.tight_layout()
plt.show()

#요약: 
# 1. 30분부터 90분까지 15분 단위로 균등하게 분포하고 있습니다.
# 2. 모든 인원이 신체활동을 하고 있습니다.
# 3. 남성은 bmi 지수가 높을수록 신체활동량이 감소하는 경향이 있지만 여성은 반대로 bmi 지수가 높을수록 신체활동량이 증가하는 경향이 있습니다.

# %%
# 일일 걸음수

# 히스토그램 + KDE
plt.figure(figsize=(12, 6))
bins = np.arange(3000, 10001, 1000)
sns.histplot(data=sleep, x='Daily Steps', bins=bins, kde=True)
plt.title('일일 걸음수 분포');plt.show()

# %% [markdown]
# ### 2-4. 정신건강 변수

# %%
# 7.스트레스 레벨
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.countplot(data=sleep, x='Stress Level',palette='coolwarm')
plt.subplot(1,2,2)
sns.regplot(data=sleep, x='Sleep Duration', y='Stress Level', scatter_kws={'alpha':0.2}, line_kws={'color': 'red'})
plt.tight_layout();plt.show();

#요약 
#1. 스트레스 레벨은 3-8까지 분포하고 있습니다.
#2. 스트레스 레벨 6,7 에서 다소 적지만 전반적으로 균등하게 분포하고 있습니다.
#3. 수면시간이 증가할수록 스트레스 레벨이 감소하는 경향이 있습니다.
# Out:
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_46610/1085066678.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sleep, x='Stress Level',palette='coolwarm')

# %% [markdown]
# ---
#
# ## 3.목표 변수 심층 분석
# 1. 목표 변수의 분포 특성 분석
# 2. 수면 품질 분석
# 3. 수면 장애 분석

# %%
# 8. 수면 품질

# 수면 품질 분포 시각화
plt.figure(figsize=(10,6))
sns.countplot(data=sleep, x='Quality of Sleep',palette='coolwarm')
plt.title('수면 품질 분포')
plt.show()
# Out:
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_46610/2279805266.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sleep, x='Quality of Sleep',palette='coolwarm')

# %%
# 9.수면 장애
sleep['Sleep Disorder'].isna().sum() #결측치 합계 확인
# Out:
# 219

# %%
# 수면장애 전처리

sleep['Sleep Disorder'] = sleep['Sleep Disorder'].fillna('None')
print(sleep['Sleep Disorder'].isna().sum()) 
print(sleep['Sleep Disorder'].value_counts())

# 수면장애 유형별 빈도수 시각화
plt.figure(figsize=(10,6))
sns.countplot(data=sleep, x='Sleep Disorder',palette='coolwarm')
plt.xticks(range(3), ['없음', '수면무호흡증', '불면증'])
plt.title('수면장애 유형별 빈도수')
plt.show()
# Out:
# 0
# Sleep Disorder
# None           219
# Sleep Apnea     78
# Insomnia        77
# Name: count, dtype: int64
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_46610/3555023162.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sleep, x='Sleep Disorder',palette='coolwarm')

# %% [markdown]
# ---
#
# ### 3-1. 수면 품질 분석
#
# 1. 수치형 변수 상관관계 분석후 수면 품질과 상관관계 높은 변수 선별
# 2. 시각화
#     * **2-1.** 나이와 성별에 따른 수면 품질 만족도 분포
#     * **2-2.** 직업별 수면 만족도
#     * **2-3.** 수면장애 유형별 수면 만족도
#     * **2-4.** 수면 시간과 수면 품질의 관계
#     * **2-5.** 스트레스 레벨과 수면 품질의 관계
#     * **2-6.** 심장 박동수와 수면 품질의 관계

# %%
# 1. 수치형 변수 상관관계 분석후 수면 품질과 상관관계 높은 변수(절댓값 0.3 이상) 선별
# Min-Max 정규화 (4-9 범위)
sleep['Sleep_Quality_normalized'] = (sleep['Quality of Sleep'] - 4) / (9 - 4)

# 정규화된 데이터로 상관관계 분석
numerical_cols = ['Sleep_Quality_normalized','Sleep Duration', 'Physical Activity Level','Stress Level', 'Heart Rate', 'Daily Steps', 'Age']
correlation_normalized = sleep[numerical_cols].corr()

#히트맵으로 상관관계 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_normalized, annot=True, cmap='coolwarm', center=0)
plt.title('수치형 변수들 간의 상관관계');plt.xticks(rotation=45, ha='right');plt.yticks(rotation=0);plt.tight_layout();plt.show()

# 밑에 나온 상관계수를 토대로 수면 품질과 관련된 변수들을 선별하여 시각화 분석을 진행하겠습니다.
# 선별된 데이터 목록 ['Sleep Duration','Stress Level','Heart Rate','Age'] 
# 상관관계 분석 안한 범주형 데이터 목록 ['Gender', 'Occupation', 'BMI Category', 'Sleep Disorder']

# %%
#2-1.나이와 성별에 따른 수면 만족도 분포
plt.figure(figsize=(10,6))
sns.kdeplot(data=sleep,x='Age',y='Quality of Sleep',hue='Gender',fill=True,alpha=0.5)
sns.scatterplot(data=sleep,x='Age',y='Quality of Sleep',hue='Gender',alpha=0.3,s=50)
plt.title('나이와 성별에 따른 수면 만족도 분포');plt.tight_layout();plt.show()
# 남성의 경우 나이와 무관하게 수면 만족도가 일정한 반면, 여성은 나이가 많아질수록 수면의 질이 향상되는 것으로 해석됩니다. 
# 그러나 비슷한 연령대의 남성과 여성을 비교했을 때는 두 성별 간 큰 차이가 관찰되지 않습니다. 
# 이를 종합하면, 남성과 여성 간 수면 만족도 차이는 단순히 성별 때문이라기보다, 나이 요인에 의해 발생한 것으로 추정할 수 있습니다.

# %%
#2-2.직업별 수면 만족도 
plt.figure(figsize=(12, 6))
sns.boxplot(x='Occupation', y='Quality of Sleep', data=sleep,palette='coolwarm')#박스 플롯
sns.stripplot(x='Occupation', y='Quality of Sleep', data=sleep, color='red', alpha=0.3)#stripplot 추가함으로서 실제 분포 확인
plt.xticks(rotation=45);plt.title('직업별 수면 만족도 분포');plt.tight_layout();plt.show()
sleep['Occupation'].value_counts()
#요약
# 1. 엔지니어가 가장 높은 수면 만족도를 보이고 있습니다.
# 2. 데이터가 적긴 하나 과학자의 수면 만족도가 가장 낮은 것으로 나타났습니다.
# Out:
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_46610/251234893.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Occupation', y='Quality of Sleep', data=sleep,palette='coolwarm')#박스 플롯
# Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64

# %%
#2-3.수면장애 유형별 수면 만족도
plt.figure(figsize=(12, 6))
sns.boxplot(data=sleep,x="Sleep Disorder",y="Quality of Sleep",palette='coolwarm')
sns.stripplot(x='Sleep Disorder', y='Quality of Sleep', data=sleep, color='red', alpha=0.5) # stripplot 추가함으로서 실제 분포 확인
plt.title('수면 장애 유형별 수면 만족도 분포');plt.ylabel('수면 만족도 점수');plt.xlabel('수면 장애 유형');plt.show()

#요약
# 1. 전반적으로 어떠한 수면 장애도 갖고 있지 않는 그룹이 가장 높은 수면 만족도를 보이고 있습니다.
# 2. 불면증을 가진 사람들이 가장 낮은 수면 만족도를 보이고 있습니다.
# 3. 특이하게도 수면 무호흡증을 가진 사람을은 수면 만족도가 9 와 6 에 몰려있습니다.
# Out:
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_46610/4233415407.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=sleep,x="Sleep Disorder",y="Quality of Sleep",palette='coolwarm')

# %%
#2-4.수면 시간과 수면 품질의 관계
plt.figure(figsize=(10, 6))
sns.regplot(data=sleep,x='Sleep Duration',y='Quality of Sleep',scatter_kws={'alpha':0.3, 's':50},line_kws={'color': 'red'},y_jitter=0.2)
# y_jitter 추가하여 겹치는 데이터 확인
plt.title('수면 시간과 수면 만족도의 관계')
plt.tight_layout()
plt.show()

#요약
# 수면 시간이 증가할수록 수면 만족도가 높은 패턴이 나타납니다.

# %%
#2-5.스트레스 레벨과 수면 품질의 관계
plt.figure(figsize=(10, 6))
sns.regplot(data=sleep,x='Stress Level',y='Quality of Sleep',scatter_kws={'alpha':0.3, 's':50},line_kws={'color': 'red'},x_jitter=0.2,y_jitter=0.2)
plt.title('스트레스와 수면 품질의 관계')
plt.tight_layout()
plt.show()

#요약
#스트레스 수준이 높을수록 수면 품질이 낮은 패턴이 나타납니다.

# %%
#2-6. 심장 박동수와 수면 품질의 관계
plt.figure(figsize=(10, 6))
sns.regplot(data=sleep,x='Heart Rate',y='Quality of Sleep',scatter_kws={'alpha':0.3, 's':50},line_kws={'color': 'red'},x_jitter=0.4,y_jitter=0.1)
plt.title('안정시 심장박동수와 수면 품질의 관계')
plt.tight_layout()
plt.show()

#요약
#심박수가 낮을수록 수면 품질이 높은 패턴이 나타납니다.

# %% [markdown]
# ---
#
# ### 3-2. 수면 장애 분석
# 1. 시각화
#     * **1-1.** 나이와 수면장애에 따른 수면 만족도 분포
#     * **1-2.** 성별과 수면 장애에 따른 수면 만족도
#     * **1-3.** BMI와 수면 장애에 따른 수면 만족도
#     * **1-4.** 직업과 수면 장애
#     * **1-5.** 신체활동량과 수면 장애
#     * **1-6.** 심박수와 수면 장애
#     * **1-7.** 수면 시간과 수면 장애

# %%
#1-1. 나이와 수면장애에 따른 수면 만족도 분포
plt.figure(figsize=(10,6))
sns.kdeplot(data=sleep,x='Age',y='Quality of Sleep',hue='Sleep Disorder',fill=True,alpha=0.3)
sns.scatterplot(data=sleep,x='Age',y='Quality of Sleep',hue='Sleep Disorder',alpha=0.3,s=50)
plt.title('나이와 수면장애에 따른 수면 만족도 분포')
plt.tight_layout()
plt.show()

#요약
#1.같은 나이를 기준으로 수면 장애가 없는 그룹이 수면 만족도가 높은 경향이 있습니다.
#2.그래프를 보면 같은 나이를 기준으로 수면 무호흡증을 가진 그룹이 수면 만족도가 가장 낮은 경향이 있습니다.
#3.나이가 많아질수록 수면 무호흡증을 가진 사람들의 분포가 많습니다.

# %%
#1-2 성별과 수면 장애에 따른 수면 만족도
plt.figure(figsize=(12, 6))
sns.boxplot(data=sleep,x="Gender",y="Quality of Sleep",hue="Sleep Disorder")
plt.title('성별과 수면 장애에 따른 수면 만족도');plt.ylabel('수면 만족도 점수');plt.xlabel('성별');plt.show()

plt.figure(figsize=(12, 6))
sleep.groupby('Sleep Disorder')['Gender'].value_counts().plot.pie(autopct ='%1.1f%%')
plt.title('수면 장애와 성별 조합별 분포');plt.axis('equal');plt.tight_layout();plt.show()
#요약
# 1. 여성은 남성보다 수면 만족도가 높은 경향이 있습니다.
# 2. 불면증을 가진 사람의 수면 만족도 분포 가 매우 좁게 분포하고 있습니다.

# %%
#1-3. BMI와 수면 장애에 따른 수면 만족도
plt.figure(figsize=(12, 6))
sns.catplot(data=sleep,x="BMI Category",y="Quality of Sleep",hue="Sleep Disorder",kind='box',height=6,aspect=2,order=['Normal', 'Overweight', 'Obese'])
plt.title('BMI와 수면 장애에 따른 수면 만족도');plt.ylabel('수면 만족도 점수');plt.xlabel('BMI');plt.show()

# %%
# 1-4 직업별 수면 장애
# 1-4 직업별 수면 장애
fig, axes = plt.subplots(3, 4, figsize=(20, 15))
axes = axes.ravel()

# 일관된 색상 매핑 설정
colors = {'None': '#2ecc71',  # 초록색
          'Insomnia': '#e74c3c',  # 빨간색
          'Sleep Apnea': '#3498db'}  # 파란색

# 각 직업별로 수면 장애 분포를 파이 차트로 시각화
for idx, occupation in enumerate(sleep['Occupation'].unique()):
    data = sleep[sleep['Occupation'] == occupation]['Sleep Disorder'].value_counts()
    # 색상 리스트 생성 (데이터 순서에 맞춰)
    color_list = [colors[disorder] for disorder in data.index]
    axes[idx].pie(data,labels=data.index,colors=color_list,autopct=lambda pct: f'{pct:.1f}%\n({int(pct/100.*sum(data))}명)')
    axes[idx].set_title(f'{occupation}', pad=10, fontsize=12, fontweight='bold')
    
plt.suptitle('직업별 수면 장애 분포');fig.delaxes(axes[11]);plt.tight_layout();plt.show()
# 요약
# 1. 엔지니어와 변호사가 수면장애가 가장 없는 것으로 나타났습니다.
# 2. 간호사나 세일즈맨을 보면 수면장애 분포가 데이터를 신뢰할수 없을 정도로 극단적으로 나왔습니다

# %%
#1-5. 신체활동량과 수면 장애

plt.figure(figsize=(10, 6))
for disorder in sleep['Sleep Disorder'].unique():
    sns.kdeplot(data=sleep[sleep['Sleep Disorder'] == disorder], 
                x='Physical Activity Level', 
                label=disorder)
plt.title('수면 장애별 신체 활동량 분포 밀도');plt.xlabel('신체 활동량');plt.ylabel('밀도');plt.legend(title='수면 장애');plt.grid(True, alpha=0.3);plt.show()
# 3. 수치적 요약
print("\n수면 장애별 신체 활동량 통계:")
print(sleep.groupby('Sleep Disorder')['Physical Activity Level'].describe().round(2))

#요약
#1.신체활동량이 많을수록 수면 무호흡증을 가진 사람들의 분포가 높게 나타났습니다.
#2.불면증을 갖은 사람들의 신체활동량이 가장 낮게 나타났습니다.
#3.결론 : 신체활동이 과도하게 많으면 수면 무호흡증에 신체활동이 과도하게 적으면 불면증에 걸릴 확률이 높아진다고 볼 수 있습니다.
# Out:
# 수면 장애별 신체 활동량 통계:
#                 count   mean    std   min   25%   50%   75%   max
# Sleep Disorder
# Insomnia         77.0  46.82  11.75  30.0  45.0  45.0  45.0  90.0
# None            219.0  57.95  20.93  30.0  30.0  60.0  75.0  90.0
# Sleep Apnea      78.0  74.79  17.93  30.0  75.0  75.0  90.0  90.0

# %%
#1-6. 심박수와 수면 장애
plt.figure(figsize=(10, 6))
for disorder in sleep['Sleep Disorder'].unique():
    sns.kdeplot(data=sleep[sleep['Sleep Disorder'] == disorder], 
                x='Heart Rate', 
                label=disorder)
    
plt.title('수면 장애별 심박수 분포 밀도');plt.xlabel('심박수');plt.ylabel('밀도');plt.legend(title='수면 장애');plt.show()

# 3. 수치적 요약
print("\n수면 장애별 심박수 통계:")
print(sleep.groupby('Sleep Disorder')['Heart Rate'].describe().round(2))
#요약
# 1. 수면 장애가 없는 사람들의 심박수 평균이 가장 낮고, 분포가 가장 낮게 나타났습니다.
# 2. 수면 무호흡증을 갖고 있는 사람들의 심박수 평균이 가장 높게 나타났습니다.
# Out:
# 수면 장애별 심박수 통계:
#                 count   mean   std   min   25%   50%   75%   max
# Sleep Disorder
# Insomnia         77.0  70.47  4.95  65.0  65.0  72.0  72.0  85.0
# None            219.0  69.02  2.66  65.0  68.0  70.0  70.0  77.0
# Sleep Apnea      78.0  73.09  5.12  68.0  68.0  75.0  75.0  86.0

# %%
#1-7. 수면 시간과 수면 장애
plt.figure(figsize=(12, 6))
for disorder in sleep['Sleep Disorder'].unique():
    sns.kdeplot(data=sleep[sleep['Sleep Disorder'] == disorder], x='Sleep Duration', label=disorder)
plt.title('수면 장애별 수면 시간 밀도 분포');plt.xlabel('수면 시간 (시간)');plt.ylabel('밀도');plt.legend();plt.show()
print(sleep.groupby('Sleep Disorder')['Sleep Duration'].describe().round(2))

# 요약
# 1. 수면 장애가 없는 사람들의 수면 시간이 평균적으로 더 크게 나타났습니다.
# 2, 불면증을 갖고 있는 사람의들의 수면 시간이 가장 짧고,시간 분포가 가장 좁게 나타나고 있습니다.
# Out:
#                 count  mean   std  min  25%  50%  75%  max
# Sleep Disorder
# Insomnia         77.0  6.59  0.39  5.9  6.4  6.5  6.6  8.3
# None            219.0  7.36  0.73  6.0  7.1  7.4  7.8  8.5
# Sleep Apnea      78.0  7.03  0.97  5.8  6.1  6.8  8.1  8.2

# %% [markdown]
# ---
#
# # 4.결론
#
# ## 4-1.수면 만족도
# ### 요약
# - 분석 결과, **나이**, **스트레스 수준**, **직업**, **수면 장애 여부**, **수면 시간**, **심박수**가 수면의 질에 유의미한 영향을 미치는 것으로 나타났습니다. 특히, 높은 스트레스는 낮은 수면의 질과 밀접한 관련이 있었습니다.
#
# #### 주요 내용
# - **나이**: 나이가 많아질수록 수면의 질이 향상되는 경향이 나타남.
# - **성별**: 여성은 남성보다 전반적으로 수면 만족도가 높은 경향이 있음.
# - **직업**: 엔지니어 직군이 가장 높은 수면 만족도를 보임.
# - **수면 장애 여부**: 수면 장애가 없는 그룹이 전반적으로 가장 높은 만족도를 나타냄.
# - **수면 시간**: 수면 시간이 길수록 수면 만족도가 높아지는 **양의 상관관계**가 있음.
# - **스트레스**: 스트레스 수준이 높을수록 수면 품질이 저하됨.
# - **심박수**: 심박수가 낮을수록 수면 품질이 향상되는 경향이 있음.
#
# ## 4-2 수면 장애
# ### 요약
# - 수면 장애는 **나이**, **성별**, **BMI**, **직업**, **신체활동량**, **심박수**, **수면 시간**과 유의미한 상관관계가 있는 것으로 나타났습니다.
#
# #### 주요 내용
# - **수면 만족도**: 같은 나이를 기준으로 수면 장애가 없는 그룹이 더 높은 수면 만족도를 보임.
# - **나이와 수면 장애**: 나이가 많아질수록 **수면 무호흡증**을 가진 사람들의 분포가 증가.
# - **직업**:
#   - **수면 장애가 적은 직업**: 엔지니어, 변호사.
#   - **수면 장애가 많은 직업**: 간호사, 영업 사원(수면 장애 비율 약 90%),교사.
# - **신체활동**:
#   - **과도한 신체활동**: 수면 무호흡증 증가.
#   - **신체활동 부족**: 불면증 비율 증가.
# - **심박수**: 수면 장애가 없는 사람들의 **평균 심박수가 가장 낮고**, 분포도 가장 낮음.
# - **수면 시간**: 수면 장애가 없는 사람들의 **수면 시간이 평균적으로 더 긴** 것으로 나타남.
#
# ## 4-3.수면의 실질적 개선 방안
# 1. 스트레스 관리:스트레스가 수면의 질에 큰 영향을 미치는 것으로 확인된 만큼, 정기적인 스트레스 관리 필요.
# 2. 직업별 수면 관리:자신의 직업이 간호사, 영업 사원, 교사와 같이 수면 장애 비율이 높은 직군이라면, 자신의 자신의 수면 건강에 더욱 주의를 기울여야 합니다.
# 3. 적정 신체활동 관리:신체활동이 너무 적거나 많으면 수면 장애에 취약해질 수 있으므로 '균형 잡힌 신체활동'이 중요합니다
# 4. 심박수 관리:안정시 심박수가 낮을수록 수면의 질이 높고 수면 장애로부터 자유로워질 수 있으므로 심박수 관리가 중요
# 5. 나이별 수면 관리:나이가 많아질수록 수면 무호흡증을 가진 사람들의 분포가 증가하므로 나이가 많아질수록 자신의 수면 건강에 더욱 주의를 기울여야 합니다.
# ---
#
# # 5. 한계점 및 개선방향
#
# ## 한계점
# - **수면 만족도의 주관성**:
#   분석의 핵심 변수인 수면 만족도는 개인의 주관적인 응답에 기반하고 있어, 객관성이 부족하다는 한계가 존재합니다.
# - **데이터 신뢰성 문제**:
#   혈압 데이터와 같이 상식적으로 이해할 수 없는 결과가 나타나 데이터의 신뢰성이 의심됩니다.
# - **데이터 품질**:
#   분석 결과 데이터 수집에서 성별과 나이의 심각한 분포 차이, 실제 사회의 다양한 직업군을 대표하지 못하는 점 등 데이터 품질에 아쉬움이 있었습니다.
#
# ---
#
# ## 개선방향
# - **객관적 지표 추가**:
#   웨어러블 장치의 데이터, 수면 시 뇌파 활동 등 객관적인 지표를 추가적으로 수집합니다.
# - **데이터 신뢰성 향상**:
#   신뢰성 있는 데이터를 직접 수집하며, 수집 단계에서 간단한 통계 분석을 통해 데이터의 품질을 검증합니다.
# - **표본 다양성 확보**:
#   데이터 수집 과정에서 잠재적인 편향과 오류를 줄이기 위해 표본의 다양성을 확보하여 대표성을 높입니다.

# %% [markdown]
# # read me:여기서부터 딥러닝 기말 대체 과제입니다!
# # read me:여기서부터 딥러닝 기말 대체 과제입니다!
# # read me:여기서부터 딥러닝 기말 대체 과제입니다!
# # read me:여기서부터 딥러닝 기말 대체 과제입니다!
# # read me:여기서부터 딥러닝 기말 대체 과제입니다!

# %% [markdown]
# ---
#
# # 딥러닝 기말 대체 과제 1
#
# ## 1.문제의 정의 및 목표
#
# * **목표: 자신의 데이터를 입력하면 자신의 수면의 질과 수면 장애 여부를 예측하는 것입니다.**
#
# 1. 수면의 질은 인생에 있어서 상당히 중요한 지표입니다. 결과를 토대로 자신의 수면의 질이 어느 정도인지 파악할 수 있게 만들었습니다.
# 2. 이 프로그램은 수면 장애 여부를 평가합니다. 결과는 참고용이며 수면장애 조기 예방과 건강관리를 위한 지표로 활용하실 수 있습니다.

# %%
# 라이브러리,데이터
import pandas as pd # 데이터 처리를 위한 라이브러리
import numpy as np  # 수치 계산을 위한 라이브러리
from sklearn.model_selection import train_test_split # 데이터 분할
from sklearn.preprocessing import StandardScaler, LabelEncoder # 데이터 전처리
from tensorflow.keras.models import Model # 케라스 모델 생성
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization # 케라스 레이어
from tensorflow.keras.utils import to_categorical  # 원-핫 인코딩
from tensorflow.keras.optimizers import Adam
# 데이터 읽기
df = pd.read_csv('sleep.csv')

# %%
# 데이터 전처리

# 분석에 사용할 중요 특성들을 선택
# 이 특성들은 수면 상태를 예측하는데 중요(위의 분석내용 토대로)하다고 판단된 변수들입니다
features = ['Sleep Duration',  # 수면 시간
            'Stress Level',    # 스트레스 수준
            'Heart Rate',      # 심박수
            'Age',            # 나이
            'Gender',         # 성별
            'Occupation',     # 직업
            'BMI Category',   # BMI 카테고리
            'Quality of Sleep',# 수면 품질
            'Sleep Disorder'] # 수면 장애

# 선택한 특성들만 포함하는 새로운 데이터프레임 생성
df_selected = df[features]

# LabelEncoder 적용, 범주형 변수를 숫자로 변환
le_gender = LabelEncoder()
le_occupation = LabelEncoder()
le_bmi = LabelEncoder()
le_sleep_disorder = LabelEncoder()

# 각각의 범주형 컬럼에 대해 레이블 인코딩 적용
df_selected['Gender'] = le_gender.fit_transform(df_selected['Gender'])
df_selected['Occupation'] = le_occupation.fit_transform(df_selected['Occupation'])
df_selected['BMI Category'] = le_bmi.fit_transform(df_selected['BMI Category'])
df_selected['Sleep Disorder'] = le_sleep_disorder.fit_transform(df_selected['Sleep Disorder'])

# 특성(X)과 타겟 변수(y)를 분리
# 두 가지를 예측하려 함: 수면 장애(disorder)와 수면 품질(quality)
X = df_selected.drop(['Sleep Disorder', 'Quality of Sleep'], axis=1) # 입력 특성
y_disorder = df_selected['Sleep Disorder'] # 첫 번째 타겟: 수면 장애
y_quality = df_selected['Quality of Sleep'] # 두 번째 타겟: 수면 품질

# 데이터를 학습용(80%)과 테스트용(20%)으로 분할
X_train, X_test, y_disorder_train, y_disorder_test, y_quality_train, y_quality_test = train_test_split(
    X, y_disorder, y_quality, test_size=0.2, random_state=42)

# 데이터 스케일링 - 모든 특성들을 동일한 스케일로 변환
# StandardScaler는 평균을 0, 표준편차를 1로 만듭니다
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)  # 학습 데이터 스케일링
X_test_scaled = scaler.transform(X_test)  # 테스트 데이터 스케일링

# 수면 장애 레이블을 원-핫 인코딩으로 변환
y_disorder_train_encoded = to_categorical(y_disorder_train)
y_disorder_test_encoded = to_categorical(y_disorder_test)
# Out:
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_46610/1727229393.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['Gender'] = le_gender.fit_transform(df_selected['Gender'])
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_46610/1727229393.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['Occupation'] = le_occupation.fit_transform(df_selected['Occupation'])
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_46610/1727229393.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['BMI Category'] = le_bmi.fit_transform(df_selected['BMI Category'])
# /var/folders/wt/523g88ps5cs2_z5dsn_yj80h0000gn/T/ipykernel_46610/1727229393.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['Sleep Disorder'] = le_sleep_disorder.fit_transform(df_selected['Sleep Disorder'])

# %%
# 모델 생성 
#모델 구조
def model(input_shape, n_disorder_classes):
    # 입력 레이어
    input_layer = Input(shape=(input_shape,))
    
     # 공유 레이어 구성 - 두 출력(disorder와 quality)이 공통으로 사용하는 층들
    x = Dense(128, activation='relu')(input_layer) # 첫 번째 은닉층, 128개 뉴런
    x = BatchNormalization()(x) # 배치 정규화 - 학습 안정화
    x = Dropout(0.3)(x)  # 30% 드롭아웃 - 과적합 방지
    
    # 두 번째 은닉층
    x = Dense(96, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    # 세 번째 은닉층
    x = Dense(64, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.25)(x)
    
     # 수면 품질 예측을 위한 분기
    quality = Dense(48, activation='relu')(x)
    quality = BatchNormalization()(quality)
    quality = Dropout(0.2)(quality)
    quality = Dense(32, activation='relu')(quality)
    quality = BatchNormalization()(quality)
    quality_output = Dense(1, name='quality_output')(quality)
    
    # 수면 장애 예측을 위한 분기
    disorder = Dense(48, activation='relu')(x)
    disorder = BatchNormalization()(disorder)
    disorder = Dropout(0.2)(disorder)
    disorder = Dense(32, activation='relu')(disorder)
    disorder = BatchNormalization()(disorder)
    disorder_output = Dense(n_disorder_classes, activation='softmax', name='disorder_output')(disorder)
    
    
    # 모델 생성
    model = Model(inputs=input_layer, outputs=[disorder_output, quality_output])
    
    # Adam 옵티마이저 설정 - 학습률 0.001
    optimizer = Adam(learning_rate=0.001)
    
    # 모델 컴파일 - 손실 함수와 평가 지표 설정
    model.compile(
        optimizer=optimizer,
        loss={
            'disorder_output': 'categorical_crossentropy', # 분류 문제의 손실 함수
            'quality_output': 'mse' # 회귀 문제의 손실 함수
        },
        loss_weights={
            'disorder_output': 1.0, # 각 가중치 동일하게 설정
            'quality_output': 1.0  
        },
        metrics={
            'disorder_output': 'accuracy', # 분류 정확도
            'quality_output': 'mae' # 평균 절대 오차
        }
    )
    
    return model

n_features = X_train.shape[1]  # 입력 특성의 수
model = model(n_features, len(le_sleep_disorder.classes_))
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 7)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │      1,024 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128)       │        512 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 96)        │     12,384 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96)        │        384 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 96)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      6,208 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 48)        │      3,120 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 48)        │      3,120 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48)        │        192 │ dense_5[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48)        │        192 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 48)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 48)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 32)        │      1,568 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 32)        │      1,568 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_6[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ disorder_output     │ (None, 3)         │         99 │ batch_normalizat… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ quality_output      │ (None, 1)         │         33 │ batch_normalizat… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 30,916 (120.77 KB)
#  Trainable params: 30,020 (117.27 KB)
#  Non-trainable params: 896 (3.50 KB)

# %%
# 모델 학습 및 결과 출력

# 모델 학습
history = model.fit(
    X_train_scaled,
    {'disorder_output': y_disorder_train_encoded,
     'quality_output': y_quality_train},
    epochs=100,  # 에포크 수
    batch_size=64,  # 배치 사이즈
    validation_split=0.2, # 학습 데이터의 20%를 검증용으로 사용
    verbose=1
)

# 모델 평가
test_results = model.evaluate(
    X_test_scaled,
    {'disorder_output': y_disorder_test_encoded,
     'quality_output': y_quality_test},
    verbose=0
)

# 평가

# 모델 평가 결과에서 각 지표 추출
disorder_accuracy = test_results[3]  # metrics에서 정의된 순서대로 값을 가져옴
disorder_output_loss = test_results[2]
quality_mae = test_results[4]
quality_output_loss = test_results[1]

# 평가 결과를 딕셔너리로 저장
evaluation_results = {
    'disorder_accuracy': disorder_accuracy,
    'disorder_loss': disorder_output_loss,
    'quality_mae': quality_mae,
    'quality_loss': quality_output_loss
}

# 결과 출력
print("\n=== 모델 평가 결과 ===")
print("\n수면 장애 예측 성능:")
print(f"- 분류 정확도: {evaluation_results['disorder_accuracy']:.2f}")
print(f"- Cross-entropy 손실: {evaluation_results['disorder_loss']:.4f}")

print("\n수면 품질 예측 성능:")
print(f"- 평균 절대 오차(1-10 척도 기준): {evaluation_results['quality_mae']:.2f}")
print(f"- MSE 손실: {evaluation_results['quality_loss']:.4f}")

# 학습 과정 시각화 함수
def plot_training_history(history):
    import matplotlib.pyplot as plt
    
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
    
    # MAE
    ax1.plot(history.history['quality_output_mae'])
    ax1.plot(history.history['val_quality_output_mae'])
    ax1.set_title('수면 품질 MAE')
    ax1.set_ylabel('MAE')
    ax1.set_xlabel('Epoch')
    ax1.legend(['훈련 데이터', '검증 데이터'])
    
    # Quality Loss
    ax2.plot(history.history['quality_output_loss'])
    ax2.plot(history.history['val_quality_output_loss'])
    ax2.set_title('수면 품질 손실')
    ax2.set_ylabel('Loss')
    ax2.set_xlabel('Epoch')
    ax2.legend(['훈련 데이터', '검증 데이터'])
    
    # Accuracy
    ax3.plot(history.history['disorder_output_accuracy'])
    ax3.plot(history.history['val_disorder_output_accuracy'])
    ax3.set_title('수면 장애 예측 정확도')
    ax3.set_ylabel('Accuracy')
    ax3.set_xlabel('Epoch')
    ax3.legend(['훈련 데이터', '검증 데이터'])
    
    # Loss
    ax4.plot(history.history['disorder_output_loss'])
    ax4.plot(history.history['val_disorder_output_loss'])
    ax4.set_title('수면 장애 Loss')
    ax4.set_ylabel('Loss')
    ax4.set_xlabel('Epoch')
    ax4.legend(['훈련 데이터', '검증 데이터'])
    
    plt.tight_layout()
    plt.show()

# 학습 과정 시각화
plot_training_history(history)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - disorder_output_accuracy: 0.2409 - disorder_output_loss: 1.6967 - loss: 57.8676 - quality_output_loss: 56.1413 - quality_output_mae: 7.3159 - val_disorder_output_accuracy: 0.5167 - val_disorder_output_loss: 1.0950 - val_loss: 58.3494 - val_quality_output_loss: 57.2543 - val_quality_output_mae: 7.4691
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.3536 - disorder_output_loss: 1.4065 - loss: 55.9325 - quality_output_loss: 54.5398 - quality_output_mae: 7.2678 - val_disorder_output_accuracy: 0.5833 - val_disorder_output_loss: 1.0865 - val_loss: 57.2854 - val_quality_output_loss: 56.1990 - val_quality_output_mae: 7.4078
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.4480 - disorder_output_loss: 1.1861 - loss: 55.0124 - quality_output_loss: 53.8305 - quality_output_mae: 7.2342 - val_disorder_output_accuracy: 0.6000 - val_disorder_output_loss: 1.0668 - val_loss: 56.4634 - val_quality_output_loss: 55.3966 - val_quality_output_mae: 7.3593
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.4274 - disorder_output_loss: 1.1590 - loss: 54.9404 - quality_output_loss: 53.7343 - quality_output_mae: 7.2185 - val_disorder_output_accuracy: 0.6167 - val_disorder_output_loss: 1.0442 - val_loss: 55.6847 - val_quality_output_loss: 54.6404 - val_quality_output_mae: 7.3104
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.4749 - disorder_output_loss: 1.1132 - loss: 53.2326 - quality_output_loss: 52.1131 - quality_output_mae: 7.1333 - val_disorder_output_accuracy: 0.6333 - val_disorder_output_loss: 1.0183 - val_loss: 54.8347 - val_quality_output_loss: 53.8165 - val_quality_output_mae: 7.2543
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.5588 - disorder_output_loss: 0.9833 - loss: 53.6854 - quality_output_loss: 52.6341 - quality_output_mae: 7.1731 - val_disorder_output_accuracy: 0.7500 - val_disorder_output_loss: 0.9904 - val_loss: 54.1289 - val_quality_output_loss: 53.1385 - val_quality_output_mae: 7.2080
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.6092 - disorder_output_loss: 0.9177 - loss: 51.8335 - quality_output_loss: 50.8908 - quality_output_mae: 7.0576 - val_disorder_output_accuracy: 0.8167 - val_disorder_output_loss: 0.9627 - val_loss: 53.4539 - val_quality_output_loss: 52.4912 - val_quality_output_mae: 7.1634
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.6087 - disorder_output_loss: 0.8794 - loss: 52.1294 - quality_output_loss: 51.1863 - quality_output_mae: 7.0816 - val_disorder_output_accuracy: 0.7833 - val_disorder_output_loss: 0.9360 - val_loss: 52.7017 - val_quality_output_loss: 51.7657 - val_quality_output_mae: 7.1132
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.6145 - disorder_output_loss: 0.8646 - loss: 51.2359 - quality_output_loss: 50.3860 - quality_output_mae: 7.0235 - val_disorder_output_accuracy: 0.7000 - val_disorder_output_loss: 0.9127 - val_loss: 51.8471 - val_quality_output_loss: 50.9344 - val_quality_output_mae: 7.0555
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.6000 - disorder_output_loss: 0.8153 - loss: 50.5755 - quality_output_loss: 49.7273 - quality_output_mae: 6.9977 - val_disorder_output_accuracy: 0.6500 - val_disorder_output_loss: 0.8893 - val_loss: 50.9226 - val_quality_output_loss: 50.0333 - val_quality_output_mae: 6.9926
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.6836 - disorder_output_loss: 0.7923 - loss: 49.6138 - quality_output_loss: 48.7765 - quality_output_mae: 6.9281 - val_disorder_output_accuracy: 0.6500 - val_disorder_output_loss: 0.8680 - val_loss: 49.9471 - val_quality_output_loss: 49.0791 - val_quality_output_mae: 6.9253
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.7354 - disorder_output_loss: 0.7108 - loss: 48.7571 - quality_output_loss: 48.0593 - quality_output_mae: 6.8587 - val_disorder_output_accuracy: 0.6500 - val_disorder_output_loss: 0.8476 - val_loss: 48.9720 - val_quality_output_loss: 48.1244 - val_quality_output_mae: 6.8571
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.7932 - disorder_output_loss: 0.6541 - loss: 48.8867 - quality_output_loss: 48.2451 - quality_output_mae: 6.8821 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.8297 - val_loss: 48.0700 - val_quality_output_loss: 47.2403 - val_quality_output_mae: 6.7937
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.7277 - disorder_output_loss: 0.7018 - loss: 48.3839 - quality_output_loss: 47.6700 - quality_output_mae: 6.8517 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.8130 - val_loss: 47.1490 - val_quality_output_loss: 46.3360 - val_quality_output_mae: 6.7283
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.7552 - disorder_output_loss: 0.6143 - loss: 47.7382 - quality_output_loss: 47.0634 - quality_output_mae: 6.8097 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.7967 - val_loss: 46.2428 - val_quality_output_loss: 45.4461 - val_quality_output_mae: 6.6627
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.7171 - disorder_output_loss: 0.6435 - loss: 46.3280 - quality_output_loss: 45.7642 - quality_output_mae: 6.7071 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.7808 - val_loss: 45.3159 - val_quality_output_loss: 44.5351 - val_quality_output_mae: 6.5949
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8162 - disorder_output_loss: 0.6063 - loss: 45.7403 - quality_output_loss: 45.0466 - quality_output_mae: 6.6697 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.7648 - val_loss: 44.4293 - val_quality_output_loss: 43.6644 - val_quality_output_mae: 6.5293
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8637 - disorder_output_loss: 0.5402 - loss: 44.6649 - quality_output_loss: 44.2005 - quality_output_mae: 6.5818 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.7500 - val_loss: 43.6797 - val_quality_output_loss: 42.9297 - val_quality_output_mae: 6.4738
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8111 - disorder_output_loss: 0.5930 - loss: 44.4399 - quality_output_loss: 43.8722 - quality_output_mae: 6.5609 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.7373 - val_loss: 42.9250 - val_quality_output_loss: 42.1877 - val_quality_output_mae: 6.4175
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8414 - disorder_output_loss: 0.5241 - loss: 43.8451 - quality_output_loss: 43.2585 - quality_output_mae: 6.5255 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.7257 - val_loss: 42.0171 - val_quality_output_loss: 41.2914 - val_quality_output_mae: 6.3486
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.7991 - disorder_output_loss: 0.6132 - loss: 42.8113 - quality_output_loss: 42.1312 - quality_output_mae: 6.4335 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.7122 - val_loss: 41.0526 - val_quality_output_loss: 40.3404 - val_quality_output_mae: 6.2759
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8350 - disorder_output_loss: 0.4598 - loss: 41.5808 - quality_output_loss: 41.1878 - quality_output_mae: 6.3629 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.6995 - val_loss: 40.0650 - val_quality_output_loss: 39.3654 - val_quality_output_mae: 6.1992
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8620 - disorder_output_loss: 0.4954 - loss: 41.4635 - quality_output_loss: 41.0028 - quality_output_mae: 6.3451 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.6873 - val_loss: 39.0056 - val_quality_output_loss: 38.3183 - val_quality_output_mae: 6.1156
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8350 - disorder_output_loss: 0.4999 - loss: 40.0646 - quality_output_loss: 39.5857 - quality_output_mae: 6.2322 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.6757 - val_loss: 38.1056 - val_quality_output_loss: 37.4299 - val_quality_output_mae: 6.0442
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8151 - disorder_output_loss: 0.5253 - loss: 39.8141 - quality_output_loss: 39.2585 - quality_output_mae: 6.2137 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.6668 - val_loss: 37.3166 - val_quality_output_loss: 36.6498 - val_quality_output_mae: 5.9805
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8278 - disorder_output_loss: 0.5319 - loss: 39.2560 - quality_output_loss: 38.6316 - quality_output_mae: 6.1626 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.6594 - val_loss: 36.6243 - val_quality_output_loss: 35.9649 - val_quality_output_mae: 5.9243
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8753 - disorder_output_loss: 0.4569 - loss: 38.5840 - quality_output_loss: 38.0137 - quality_output_mae: 6.1190 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.6529 - val_loss: 36.0167 - val_quality_output_loss: 35.3638 - val_quality_output_mae: 5.8757
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8525 - disorder_output_loss: 0.5006 - loss: 36.8903 - quality_output_loss: 36.4030 - quality_output_mae: 5.9861 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.6470 - val_loss: 35.1888 - val_quality_output_loss: 34.5419 - val_quality_output_mae: 5.8093
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8350 - disorder_output_loss: 0.5343 - loss: 35.9486 - quality_output_loss: 35.4563 - quality_output_mae: 5.9087 - val_disorder_output_accuracy: 0.6833 - val_disorder_output_loss: 0.6399 - val_loss: 34.3384 - val_quality_output_loss: 33.6985 - val_quality_output_mae: 5.7396
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8319 - disorder_output_loss: 0.5290 - loss: 34.5505 - quality_output_loss: 33.9414 - quality_output_mae: 5.7736 - val_disorder_output_accuracy: 0.6667 - val_disorder_output_loss: 0.6329 - val_loss: 33.1378 - val_quality_output_loss: 32.5049 - val_quality_output_mae: 5.6379
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8600 - disorder_output_loss: 0.4303 - loss: 33.7269 - quality_output_loss: 33.3429 - quality_output_mae: 5.7134 - val_disorder_output_accuracy: 0.6833 - val_disorder_output_loss: 0.6231 - val_loss: 32.0292 - val_quality_output_loss: 31.4061 - val_quality_output_mae: 5.5423
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8351 - disorder_output_loss: 0.4907 - loss: 33.5455 - quality_output_loss: 33.0478 - quality_output_mae: 5.6999 - val_disorder_output_accuracy: 0.7167 - val_disorder_output_loss: 0.6132 - val_loss: 30.9113 - val_quality_output_loss: 30.2981 - val_quality_output_mae: 5.4458
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8633 - disorder_output_loss: 0.4286 - loss: 32.4133 - quality_output_loss: 31.9697 - quality_output_mae: 5.5970 - val_disorder_output_accuracy: 0.7333 - val_disorder_output_loss: 0.6029 - val_loss: 29.8954 - val_quality_output_loss: 29.2925 - val_quality_output_mae: 5.3563
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8591 - disorder_output_loss: 0.4453 - loss: 31.9265 - quality_output_loss: 31.4230 - quality_output_mae: 5.5682 - val_disorder_output_accuracy: 0.7500 - val_disorder_output_loss: 0.5979 - val_loss: 28.8832 - val_quality_output_loss: 28.2853 - val_quality_output_mae: 5.2637
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8771 - disorder_output_loss: 0.4290 - loss: 31.0736 - quality_output_loss: 30.6085 - quality_output_mae: 5.4738 - val_disorder_output_accuracy: 0.7667 - val_disorder_output_loss: 0.5925 - val_loss: 27.8503 - val_quality_output_loss: 27.2578 - val_quality_output_mae: 5.1671
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8910 - disorder_output_loss: 0.4418 - loss: 28.9894 - quality_output_loss: 28.5846 - quality_output_mae: 5.2823 - val_disorder_output_accuracy: 0.7500 - val_disorder_output_loss: 0.5865 - val_loss: 26.8177 - val_quality_output_loss: 26.2312 - val_quality_output_mae: 5.0689
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8816 - disorder_output_loss: 0.3952 - loss: 28.7845 - quality_output_loss: 28.4137 - quality_output_mae: 5.2696 - val_disorder_output_accuracy: 0.7500 - val_disorder_output_loss: 0.5811 - val_loss: 26.0322 - val_quality_output_loss: 25.4511 - val_quality_output_mae: 4.9917
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8754 - disorder_output_loss: 0.3902 - loss: 27.5041 - quality_output_loss: 27.1339 - quality_output_mae: 5.1611 - val_disorder_output_accuracy: 0.8000 - val_disorder_output_loss: 0.5737 - val_loss: 25.5411 - val_quality_output_loss: 24.9674 - val_quality_output_mae: 4.9437
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8573 - disorder_output_loss: 0.4291 - loss: 26.4309 - quality_output_loss: 26.0161 - quality_output_mae: 5.0507 - val_disorder_output_accuracy: 0.8167 - val_disorder_output_loss: 0.5666 - val_loss: 24.8579 - val_quality_output_loss: 24.2913 - val_quality_output_mae: 4.8760
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8720 - disorder_output_loss: 0.3876 - loss: 26.0684 - quality_output_loss: 25.6488 - quality_output_mae: 5.0010 - val_disorder_output_accuracy: 0.8167 - val_disorder_output_loss: 0.5580 - val_loss: 24.1511 - val_quality_output_loss: 23.5931 - val_quality_output_mae: 4.8055
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8764 - disorder_output_loss: 0.4013 - loss: 24.9064 - quality_output_loss: 24.5369 - quality_output_mae: 4.8949 - val_disorder_output_accuracy: 0.8333 - val_disorder_output_loss: 0.5515 - val_loss: 23.3462 - val_quality_output_loss: 22.7947 - val_quality_output_mae: 4.7210
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8524 - disorder_output_loss: 0.4336 - loss: 24.8105 - quality_output_loss: 24.3008 - quality_output_mae: 4.8639 - val_disorder_output_accuracy: 0.8500 - val_disorder_output_loss: 0.5449 - val_loss: 22.5858 - val_quality_output_loss: 22.0410 - val_quality_output_mae: 4.6404
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - disorder_output_accuracy: 0.8773 - disorder_output_loss: 0.4547 - loss: 23.4666 - quality_output_loss: 23.0561 - quality_output_mae: 4.7324 - val_disorder_output_accuracy: 0.8500 - val_disorder_output_loss: 0.5372 - val_loss: 21.7095 - val_quality_output_loss: 21.1722 - val_quality_output_mae: 4.5451
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8717 - disorder_output_loss: 0.4350 - loss: 22.2389 - quality_output_loss: 21.7743 - quality_output_mae: 4.6205 - val_disorder_output_accuracy: 0.8500 - val_disorder_output_loss: 0.5289 - val_loss: 20.6882 - val_quality_output_loss: 20.1593 - val_quality_output_mae: 4.4327
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8676 - disorder_output_loss: 0.4437 - loss: 21.0155 - quality_output_loss: 20.6249 - quality_output_mae: 4.4602 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5231 - val_loss: 19.6517 - val_quality_output_loss: 19.1285 - val_quality_output_mae: 4.3190
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8564 - disorder_output_loss: 0.4574 - loss: 21.1203 - quality_output_loss: 20.6504 - quality_output_mae: 4.4746 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5186 - val_loss: 18.7984 - val_quality_output_loss: 18.2798 - val_quality_output_mae: 4.2246
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8864 - disorder_output_loss: 0.4128 - loss: 18.8659 - quality_output_loss: 18.4699 - quality_output_mae: 4.2487 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5119 - val_loss: 18.1236 - val_quality_output_loss: 17.6117 - val_quality_output_mae: 4.1520
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8869 - disorder_output_loss: 0.3749 - loss: 18.5514 - quality_output_loss: 18.2047 - quality_output_mae: 4.2082 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5082 - val_loss: 17.5438 - val_quality_output_loss: 17.0355 - val_quality_output_mae: 4.0848
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8852 - disorder_output_loss: 0.3798 - loss: 18.5483 - quality_output_loss: 18.1542 - quality_output_mae: 4.1884 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5095 - val_loss: 16.9191 - val_quality_output_loss: 16.4096 - val_quality_output_mae: 4.0036
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8436 - disorder_output_loss: 0.4091 - loss: 16.9478 - quality_output_loss: 16.5338 - quality_output_mae: 3.9897 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5113 - val_loss: 16.1247 - val_quality_output_loss: 15.6134 - val_quality_output_mae: 3.8964
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8996 - disorder_output_loss: 0.3849 - loss: 16.5349 - quality_output_loss: 16.1581 - quality_output_mae: 3.9388 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5102 - val_loss: 15.3453 - val_quality_output_loss: 14.8351 - val_quality_output_mae: 3.7911
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8650 - disorder_output_loss: 0.4587 - loss: 15.5413 - quality_output_loss: 15.0518 - quality_output_mae: 3.8115 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5106 - val_loss: 14.5562 - val_quality_output_loss: 14.0456 - val_quality_output_mae: 3.6904
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - disorder_output_accuracy: 0.8988 - disorder_output_loss: 0.3901 - loss: 15.2725 - quality_output_loss: 14.8851 - quality_output_mae: 3.7787 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5154 - val_loss: 13.7622 - val_quality_output_loss: 13.2468 - val_quality_output_mae: 3.5903
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - disorder_output_accuracy: 0.9025 - disorder_output_loss: 0.3570 - loss: 14.4580 - quality_output_loss: 14.0298 - quality_output_mae: 3.6937 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5195 - val_loss: 13.0568 - val_quality_output_loss: 12.5373 - val_quality_output_mae: 3.5015
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8788 - disorder_output_loss: 0.3578 - loss: 13.5116 - quality_output_loss: 13.1519 - quality_output_mae: 3.5471 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5196 - val_loss: 12.5001 - val_quality_output_loss: 11.9805 - val_quality_output_mae: 3.4282
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8766 - disorder_output_loss: 0.3681 - loss: 13.1339 - quality_output_loss: 12.7899 - quality_output_mae: 3.4852 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5201 - val_loss: 11.9321 - val_quality_output_loss: 11.4120 - val_quality_output_mae: 3.3459
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8702 - disorder_output_loss: 0.3732 - loss: 12.7100 - quality_output_loss: 12.2986 - quality_output_mae: 3.4265 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5184 - val_loss: 11.1956 - val_quality_output_loss: 10.6772 - val_quality_output_mae: 3.2338
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.9080 - disorder_output_loss: 0.3678 - loss: 11.4459 - quality_output_loss: 11.0633 - quality_output_mae: 3.2453 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5144 - val_loss: 10.5475 - val_quality_output_loss: 10.0331 - val_quality_output_mae: 3.1292
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8774 - disorder_output_loss: 0.3996 - loss: 10.5535 - quality_output_loss: 10.1765 - quality_output_mae: 3.1216 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5106 - val_loss: 10.0340 - val_quality_output_loss: 9.5234 - val_quality_output_mae: 3.0467
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.9099 - disorder_output_loss: 0.3611 - loss: 9.7920 - quality_output_loss: 9.4329 - quality_output_mae: 2.9847 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5127 - val_loss: 9.4316 - val_quality_output_loss: 8.9188 - val_quality_output_mae: 2.9458
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8762 - disorder_output_loss: 0.3694 - loss: 9.6960 - quality_output_loss: 9.3101 - quality_output_mae: 2.9852 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5185 - val_loss: 8.7929 - val_quality_output_loss: 8.2744 - val_quality_output_mae: 2.8346
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8944 - disorder_output_loss: 0.3196 - loss: 9.3102 - quality_output_loss: 8.9609 - quality_output_mae: 2.9298 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5240 - val_loss: 8.2560 - val_quality_output_loss: 7.7319 - val_quality_output_mae: 2.7424
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8847 - disorder_output_loss: 0.3980 - loss: 8.2101 - quality_output_loss: 7.8295 - quality_output_mae: 2.7187 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5262 - val_loss: 7.8543 - val_quality_output_loss: 7.3281 - val_quality_output_mae: 2.6714
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8754 - disorder_output_loss: 0.4029 - loss: 7.9798 - quality_output_loss: 7.5687 - quality_output_mae: 2.6750 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5281 - val_loss: 7.5634 - val_quality_output_loss: 7.0352 - val_quality_output_mae: 2.6176
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8599 - disorder_output_loss: 0.3990 - loss: 7.6007 - quality_output_loss: 7.1816 - quality_output_mae: 2.6045 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5288 - val_loss: 7.2399 - val_quality_output_loss: 6.7110 - val_quality_output_mae: 2.5559
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8892 - disorder_output_loss: 0.3561 - loss: 7.0949 - quality_output_loss: 6.7448 - quality_output_mae: 2.4848 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5308 - val_loss: 6.8132 - val_quality_output_loss: 6.2824 - val_quality_output_mae: 2.4717
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8841 - disorder_output_loss: 0.4002 - loss: 6.6464 - quality_output_loss: 6.2315 - quality_output_mae: 2.3992 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5339 - val_loss: 6.3135 - val_quality_output_loss: 5.7795 - val_quality_output_mae: 2.3667
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8991 - disorder_output_loss: 0.3348 - loss: 5.8521 - quality_output_loss: 5.5125 - quality_output_mae: 2.2413 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5379 - val_loss: 5.8986 - val_quality_output_loss: 5.3607 - val_quality_output_mae: 2.2777
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.9184 - disorder_output_loss: 0.3194 - loss: 5.4696 - quality_output_loss: 5.1631 - quality_output_mae: 2.1928 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5422 - val_loss: 5.4874 - val_quality_output_loss: 4.9452 - val_quality_output_mae: 2.1906
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8763 - disorder_output_loss: 0.4473 - loss: 5.4626 - quality_output_loss: 5.0345 - quality_output_mae: 2.1271 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5468 - val_loss: 5.1438 - val_quality_output_loss: 4.5969 - val_quality_output_mae: 2.1132
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8747 - disorder_output_loss: 0.4151 - loss: 4.6981 - quality_output_loss: 4.3170 - quality_output_mae: 1.9695 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5492 - val_loss: 4.8565 - val_quality_output_loss: 4.3073 - val_quality_output_mae: 2.0437
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8749 - disorder_output_loss: 0.4245 - loss: 4.8924 - quality_output_loss: 4.4458 - quality_output_mae: 2.0218 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5533 - val_loss: 4.5535 - val_quality_output_loss: 4.0002 - val_quality_output_mae: 1.9673
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8854 - disorder_output_loss: 0.3635 - loss: 4.1012 - quality_output_loss: 3.7438 - quality_output_mae: 1.8258 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5574 - val_loss: 4.1780 - val_quality_output_loss: 3.6206 - val_quality_output_mae: 1.8727
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8968 - disorder_output_loss: 0.3116 - loss: 4.3825 - quality_output_loss: 4.0442 - quality_output_mae: 1.9116 - val_disorder_output_accuracy: 0.8667 - val_disorder_output_loss: 0.5599 - val_loss: 3.7196 - val_quality_output_loss: 3.1597 - val_quality_output_mae: 1.7497
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8670 - disorder_output_loss: 0.3729 - loss: 3.6926 - quality_output_loss: 3.3252 - quality_output_mae: 1.7279 - val_disorder_output_accuracy: 0.8833 - val_disorder_output_loss: 0.5628 - val_loss: 3.2762 - val_quality_output_loss: 2.7134 - val_quality_output_mae: 1.6190
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.9187 - disorder_output_loss: 0.2983 - loss: 3.6181 - quality_output_loss: 3.3118 - quality_output_mae: 1.6857 - val_disorder_output_accuracy: 0.8833 - val_disorder_output_loss: 0.5609 - val_loss: 2.8927 - val_quality_output_loss: 2.3318 - val_quality_output_mae: 1.4943
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8821 - disorder_output_loss: 0.3827 - loss: 3.0501 - quality_output_loss: 2.6677 - quality_output_mae: 1.5281 - val_disorder_output_accuracy: 0.8833 - val_disorder_output_loss: 0.5553 - val_loss: 2.6518 - val_quality_output_loss: 2.0966 - val_quality_output_mae: 1.4138
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8903 - disorder_output_loss: 0.3798 - loss: 2.9941 - quality_output_loss: 2.6106 - quality_output_mae: 1.4861 - val_disorder_output_accuracy: 0.8833 - val_disorder_output_loss: 0.5515 - val_loss: 2.5285 - val_quality_output_loss: 1.9770 - val_quality_output_mae: 1.3669
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.9015 - disorder_output_loss: 0.3450 - loss: 2.8342 - quality_output_loss: 2.4683 - quality_output_mae: 1.4666 - val_disorder_output_accuracy: 0.8833 - val_disorder_output_loss: 0.5488 - val_loss: 2.4109 - val_quality_output_loss: 1.8621 - val_quality_output_mae: 1.3210
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8685 - disorder_output_loss: 0.3448 - loss: 2.4569 - quality_output_loss: 2.1048 - quality_output_mae: 1.3161 - val_disorder_output_accuracy: 0.8833 - val_disorder_output_loss: 0.5477 - val_loss: 2.2644 - val_quality_output_loss: 1.7168 - val_quality_output_mae: 1.2598
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8962 - disorder_output_loss: 0.3543 - loss: 2.3323 - quality_output_loss: 1.9875 - quality_output_mae: 1.2924 - val_disorder_output_accuracy: 0.8833 - val_disorder_output_loss: 0.5515 - val_loss: 2.1245 - val_quality_output_loss: 1.5730 - val_quality_output_mae: 1.2004
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.9105 - disorder_output_loss: 0.3313 - loss: 2.1471 - quality_output_loss: 1.8338 - quality_output_mae: 1.2097 - val_disorder_output_accuracy: 0.8833 - val_disorder_output_loss: 0.5562 - val_loss: 1.9326 - val_quality_output_loss: 1.3765 - val_quality_output_mae: 1.1177
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8952 - disorder_output_loss: 0.3304 - loss: 2.0448 - quality_output_loss: 1.7002 - quality_output_mae: 1.1643 - val_disorder_output_accuracy: 0.8833 - val_disorder_output_loss: 0.5634 - val_loss: 1.7786 - val_quality_output_loss: 1.2153 - val_quality_output_mae: 1.0532
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8619 - disorder_output_loss: 0.3731 - loss: 1.9758 - quality_output_loss: 1.5918 - quality_output_mae: 1.1175 - val_disorder_output_accuracy: 0.9000 - val_disorder_output_loss: 0.5719 - val_loss: 1.6392 - val_quality_output_loss: 1.0673 - val_quality_output_mae: 0.9853
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.9163 - disorder_output_loss: 0.2821 - loss: 1.8144 - quality_output_loss: 1.5289 - quality_output_mae: 1.1177 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.5799 - val_loss: 1.5556 - val_quality_output_loss: 0.9757 - val_quality_output_mae: 0.9408
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8929 - disorder_output_loss: 0.3459 - loss: 1.6810 - quality_output_loss: 1.3371 - quality_output_mae: 0.9806 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.5853 - val_loss: 1.4947 - val_quality_output_loss: 0.9094 - val_quality_output_mae: 0.9020
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.9041 - disorder_output_loss: 0.3263 - loss: 1.4775 - quality_output_loss: 1.1685 - quality_output_mae: 0.9439 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.5934 - val_loss: 1.4263 - val_quality_output_loss: 0.8330 - val_quality_output_mae: 0.8652
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.9088 - disorder_output_loss: 0.3018 - loss: 1.4433 - quality_output_loss: 1.1371 - quality_output_mae: 0.9040 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.5985 - val_loss: 1.3461 - val_quality_output_loss: 0.7476 - val_quality_output_mae: 0.8165
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.9047 - disorder_output_loss: 0.3358 - loss: 1.2990 - quality_output_loss: 0.9606 - quality_output_mae: 0.8478 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.6035 - val_loss: 1.2757 - val_quality_output_loss: 0.6722 - val_quality_output_mae: 0.7601
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.9002 - disorder_output_loss: 0.3187 - loss: 1.3003 - quality_output_loss: 0.9987 - quality_output_mae: 0.8262 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.6082 - val_loss: 1.2426 - val_quality_output_loss: 0.6344 - val_quality_output_mae: 0.7105
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.9157 - disorder_output_loss: 0.3290 - loss: 1.2723 - quality_output_loss: 0.9363 - quality_output_mae: 0.8362 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.6153 - val_loss: 1.1966 - val_quality_output_loss: 0.5813 - val_quality_output_mae: 0.6860
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8929 - disorder_output_loss: 0.3142 - loss: 1.1665 - quality_output_loss: 0.8512 - quality_output_mae: 0.7680 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.6252 - val_loss: 1.1475 - val_quality_output_loss: 0.5223 - val_quality_output_mae: 0.6619
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8871 - disorder_output_loss: 0.3725 - loss: 1.1903 - quality_output_loss: 0.8106 - quality_output_mae: 0.7638 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.6337 - val_loss: 1.1288 - val_quality_output_loss: 0.4951 - val_quality_output_mae: 0.6545
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8799 - disorder_output_loss: 0.3894 - loss: 0.9920 - quality_output_loss: 0.5991 - quality_output_mae: 0.6554 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.6432 - val_loss: 1.1337 - val_quality_output_loss: 0.4905 - val_quality_output_mae: 0.6376
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.9044 - disorder_output_loss: 0.3677 - loss: 1.0711 - quality_output_loss: 0.7016 - quality_output_mae: 0.7082 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.6508 - val_loss: 1.0670 - val_quality_output_loss: 0.4162 - val_quality_output_mae: 0.5843
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8915 - disorder_output_loss: 0.3800 - loss: 1.0731 - quality_output_loss: 0.6822 - quality_output_mae: 0.6396 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.6595 - val_loss: 1.0016 - val_quality_output_loss: 0.3421 - val_quality_output_mae: 0.5311
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - disorder_output_accuracy: 0.8947 - disorder_output_loss: 0.3608 - loss: 0.9755 - quality_output_loss: 0.6222 - quality_output_mae: 0.6149 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.6663 - val_loss: 0.9842 - val_quality_output_loss: 0.3179 - val_quality_output_mae: 0.4993
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8849 - disorder_output_loss: 0.3508 - loss: 0.8618 - quality_output_loss: 0.5095 - quality_output_mae: 0.6033 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.6710 - val_loss: 0.9798 - val_quality_output_loss: 0.3087 - val_quality_output_mae: 0.4930
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.8732 - disorder_output_loss: 0.3364 - loss: 0.8383 - quality_output_loss: 0.5075 - quality_output_mae: 0.5863 - val_disorder_output_accuracy: 0.9000 - val_disorder_output_loss: 0.6750 - val_loss: 0.9508 - val_quality_output_loss: 0.2758 - val_quality_output_mae: 0.4780
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - disorder_output_accuracy: 0.9271 - disorder_output_loss: 0.2832 - loss: 0.8235 - quality_output_loss: 0.5438 - quality_output_mae: 0.5908 - val_disorder_output_accuracy: 0.9167 - val_disorder_output_loss: 0.6800 - val_loss: 0.9439 - val_quality_output_loss: 0.2639 - val_quality_output_mae: 0.4631
#
# === 모델 평가 결과 ===
#
# 수면 장애 예측 성능:
# - 분류 정확도: 0.85
# - Cross-entropy 손실: 0.2722
#
# 수면 품질 예측 성능:
# - 평균 절대 오차(1-10 척도 기준): 0.47
# - MSE 손실: 0.4415

# %% [markdown]
# # 모델 평가
#
# ## **1. 학습, 검증, 테스트 결과 요약**
#
# | Metric                       | Training   | Validation   | Test   |
# |------------------------------|------------|--------------|--------|
# | Disorder Accuracy            | 92.71%     | 91.67%       | 85.33% |
# | Disorder Loss                | 0.2832     | 0.6800       | 0.2722 |
# | Quality MAE                  | 0.5908     | 0.4631       | 0.4691 |
# | Quality Loss                 | 0.5438     | 0.2639       | 0.4415 |
# | Overall Loss                 | 0.8235     | 0.9439       | null   |
#
# ---
#
# ## **2. 수면 장애 예측 모델 평가**
#
# ### **정확도**
# - **Training Accuracy**: 92.71%
# - **Validation Accuracy**: 91.67%
# - **Test Accuracy**: 85.33%
#   - 테스트 데이터의 정확도는 학습 데이터보다 낮고, 검증 데이터보다 약간 낮습니다.
#   - 이는 모델이 테스트 데이터에서 새로운 데이터를 처리할 때 다소 어려움을 겪고 있음을 나타냅니다.
#   - 하지만 여전히 85.33%의 정확도로, 테스트 데이터에서 **좋은 분류 성능**을 보였습니다.
#
# ### **손실**
# - 테스트 데이터의 분류 손실(`0.2722`)은 학습 손실(`0.2832`)과 유사하거나 약간 낮습니다.
# - 이는 모델이 **테스트 데이터에서도 학습 데이터와 유사한 분류 성능**을 발휘하고 있음을 나타냅니다.
# - **검증 손실(`0.6800`)보다 훨씬 낮음**:
#   - 학습 중 과적합이 크지 않으며, 검증 데이터에서 발생한 약간의 손실 증가가 테스트 데이터에서는 보완되었습니다.
#   - 테스트 정확도가 학습 데이터보다 낮은 점을 고려하면, 약간 과적합 되어있다고 볼 수 있습니다.
#
# ---
# ## **3. 수면의 질 예측 모델 평가**
#
# ### **MAE**
# - **Training MAE**: 0.5908
# - **Validation MAE**: 0.4631
# - **Test MAE**: 0.4691
#   - 검증 MAE와 테스트 MAE가 거의 유사하며, 학습 MAE보다 낮습니다.
#   - 이는 모델이 테스트 데이터에서 **회귀 타겟에 대해 잘 일반화**되었음을 보여줍니다.
#
# ### **손실**
# - **Training Loss**: 0.5438
# - **Validation Loss**: 0.2639
# - **Test Loss**: 0.4415
#   - 테스트 손실은 검증 손실보다 약간 높으나, 학습 손실보다는 낮습니다.
# ---
# ## **4.결론**
# - 수면 장애 예측 모델은 테스트 데이터에서 약 85센트의 정확도를 보였습니다.
# - 수면의 질 예측 모델은 테스트 데이터에서 약 0.44 정도의 오차를 보이고 있는데, 이는 10점 척도에서 양호한 수준입니다.
#
# ---

# %%
# 에측 함수 정의 및 실행 (실행 후 데이터를 넣어보세요.) 
# 예측 함수
def predict_sleep_metrics(features_dict):
    # pandas DataFrame으로 변환하면서 특성 이름 지정
    features = pd.DataFrame([[
        features_dict['Sleep Duration'],
        features_dict['Stress Level'],
        features_dict['Heart Rate'],
        features_dict['Age'],
        le_gender.transform([features_dict['Gender']])[0],
        le_occupation.transform([features_dict['Occupation']])[0],
        le_bmi.transform([features_dict['BMI Category']])[0]
    ]], columns=['Sleep Duration', 'Stress Level', 'Heart Rate', 'Age', 
                'Gender', 'Occupation', 'BMI Category'])
    
    # 이제 스케일링할 때 특성 이름이 유지됩니다
    features_scaled = scaler.transform(features)
    disorder_pred, quality_pred = model.predict(features_scaled)
    predicted_disorder = le_sleep_disorder.inverse_transform([np.argmax(disorder_pred[0])])[0]
    predicted_quality = quality_pred[0][0]
    
    return {
        'predicted_disorder': predicted_disorder,
        'predicted_quality': predicted_quality
    }

def predict_sleep():
    print("\n=== 수면의 질, 수면 장애 예측===")
    
    # 사용자로부터 입력 받기
    sleep_duration = float(input("수면 시간을 입력하세요 (시간): "))
    stress_level = int(input("스트레스 레벨을 입력하세요 (1-10): "))
    heart_rate = int(input("안정시 심박수를 입력하세요 (bpm): "))
    age = int(input("나이를 입력하세요: "))
    gender = input("성별을 입력하세요 (Male/Female): ")
    occupation = input("직업을 입력하세요:(Doctor, Engineer, Lawyer, Manager, Nurse, Sales Representative, Salesperson, Software Engineer, Teacher]),없다면 비슷한 직종을 선택해주세요.")
    bmi_category = input("BMI 카테고리를 입력하세요 (Normal/Overweight/Obese): ")
    
    # 입력값을 딕셔너리로 구성
    input_data = {
        'Sleep Duration': sleep_duration,
        'Stress Level': stress_level,
        'Heart Rate': heart_rate,
        'Age': age,
        'Gender': gender,
        'Occupation': occupation,
        'BMI Category': bmi_category
    }
    
    # 예측 수행
    result = predict_sleep_metrics(input_data)
    
    # 결과 출력
    print("\n=== 예측 결과 ===")
    print(f"예상되는 수면 장애: {result['predicted_disorder']}")
    print(f"예상되는 수면 품질 점수: {result['predicted_quality']:.1f}/10")

# 함수 실행
predict_sleep()
# Out:
# === 수면의 질, 수면 장애 예측===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
#
# === 예측 결과 ===
# 예상되는 수면 장애: nan
# 예상되는 수면 품질 점수: 7.1/10
